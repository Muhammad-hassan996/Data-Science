# %%
import pandas as pd 

data=pd.read_csv(r"C:\Users\hassa\OneDrive\Desktop\salary_data.csv")

data.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
data.isnull().sum()
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# dtype: bool

# %%
data['Position'].unique()
# Out:
# array(['Business Analyst', 'Junior Consultant', 'Senior Consultant',
#        'Manager', 'Country Manager', 'Region Manager', 'Partner',
#        'Senior Partner', 'C-level', 'CEO'], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Level'],data['Salary'])
plt.plot()
# Out:
# []

# %%
x = df[['Level']]
x
y = df['Salary']
y
# Out:
# 0       45000
# 1       50000
# 2       60000
# 3       80000
# 4      110000
# 5      150000
# 6      200000
# 7      300000
# 8      500000
# 9     1000000
# 10      45000
# 11      50000
# 12      60000
# 13      80000
# 14     110000
# 15     150000
# 16     200000
# 17     300000
# 18     500000
# 19    1000000
# 20      45000
# 21      50000
# 22      60000
# 23      80000
# 24     110000
# 25     150000
# 26     200000
# 27     300000
# 28     500000
# 29    1000000
# 30      45000
# 31      50000
# 32      60000
# 33      80000
# 34     110000
# 35     150000
# 36     200000
# 37     300000
# 38     500000
# 39    1000000
# Name: Salary, dtype: int64

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y, color='red')
plt.plot(x,y, color='blue')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19044\3537885222.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
model.score(x,y)
# Out:
# 0.6690412331929894

# %%
model.predict([[2.5]])
# Out:
# C:\Users\hassa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6863.63636364])

# %%
poly = PolynomialFeatures(degree = 2)

# %%
x_poly = poly.fit_transform(x)

# %%
reg2 = LinearRegression()

# %%
reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
reg2.predict(poly.fit_transform([[2.5]]))
# Out:
# array([21437.5])

# %%
reg2.score(x_poly,y)
# Out:
# 0.9162082221443942

# %%
reg2.predict(poly.fit_transform([[2.5]]))
# Out:
# array([21437.5])
